# %%
#program to convert kilometer into miles
k=float(input("Enter the distance in kilometers:"))
m=round(k*0.62137,2)
print("Enter the corresponding miles:",m)
# Out:
# Enter the distance in kilometers: 59
# Enter the corresponding miles: 36.66

# %%
#program to convert celsius to fahrenheit
c=float(input("Enter the temprature in celsius:"))
f=(c*9/5)+32
print("Enter the corresponding fahrenheit:",f)
# Out:
# Enter the temprature in celsius: 89
# Enter the corresponding fahrenheit: 192.2
