# %%
#printout all colors from color1 not contained in color2
color1={"red","yellow","blue"}
color2={"orange","green","blue"}
difference_color=color1.difference(color2)
print(difference_color)
# Out:
# {'red', 'yellow'}

# %%
#printout all colors from color1 and color2
color_1={"red","yellow"}
color_2={"green","blue"}
union_color=color_1|color_2
print(union_color)
# Out:
# {'red', 'blue', 'green', 'yellow'}
