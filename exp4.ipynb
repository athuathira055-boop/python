# %%
#display 1st and last color
colors=input("orginal list:")
colors=colors.split(",")
print("first color:",colors[0])
print("second color:",colors[-1])
# Out:
# orginal list: black,pink,yellow
# first color: black
# second color: yellow

# %%
#extension of file
file=input("Enter the file name:")
extension=file.split(".")[-1]
print("file extension:",extension)
# Out:
# Enter the file name: stack.c
# file extension: c

# %%
#sum and list of numbers
number=input("Enter the numbers:")
lists=list(map(int,number.split(",")))
print("list is:",lists)
print("sum is:",sum(lists))
# Out:
# Enter the numbers: 1,2,3,4,5
# list is: [1, 2, 3, 4, 5]
# sum is: 15
