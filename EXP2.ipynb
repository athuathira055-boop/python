# %%
#program to convert celsius to fahrenheit
c=float(input("Enter the temprature in celsius:"))
f=(c*9/5)+32
print("Enter the corresponding fahrenheit:",f)
# Out:
# Enter the temprature in celsius:35
# Enter the corresponding fahrenheit: 95.0

# %%
#program to convert kilometer into miles
km=float(input("Enter the distance in kilometers:"))
m=km*0.62137
print("Enter the corresponding miles:",m)
# Out:
# Enter the distance in kilometers:5
# Enter the corresponding miles: 3.1068499999999997
